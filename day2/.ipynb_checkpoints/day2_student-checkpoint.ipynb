# %% [markdown]
# ## Day 2 Notebook
# This notebook covers building a neural network by hand using numpy and then training a NN on the Fashion MNIST dataset using Keras and optimizing hyperparameters.

# %% [markdown]
# ## Part 1: Neural Networks by Hand

# %% [markdown]
# Here we'll build a 3-layer neural network from scratch and apply it to a generated dataset. This exercise is adapted from [Denny Britz](https://github.com/dennybritz/nn-from-scratch). Although it's easy to build NNs in a few lines of code using libraries like Keras (as we'll do later) it helps build intuition to implement one from basic Python functionalities first.

# %%
# Package imports
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib

# Display plots inline and change default figure size
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# ### Generating the dataset
# Let's create a dataset to experiment on. We'll use the [make_moons](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html) function from scikit-learn.

# %%
# Generate a dataset and plot it
np.random.seed(0)
X, y = sklearn.datasets.make_moons(200, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# Our dataset has two classes which are plotted as red and blue points. You can think of these as any two classes you want, let's call them Netflix show's you'll like (red) and shows you won't like (blue). The goal is to automatically separate the red and blue shows using information from the x and y coordinates (which might be length of movie and year released...although obviously in reality that likely wouldn't give us much interesting information).
#
# As you can see, you can't linear separate the two classes using the existing features. That's why a neural network is a promising model to use as a classifier. To demonstrate this, let's try a simple linear regression model.

# %%
# Train the logistic regression classifier
clf = sklearn.linear_model.LogisticRegressionCV()
clf.fit(X, y)
# Out:
# LogisticRegressionCV()

# %%
# Helper function to plot a decision boundary.
# If you don't fully understand this function don't worry, it just generates the contour plot below.
def plot_decision_boundary(pred_func):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %%
# Plot the decision boundary
plot_decision_boundary(lambda x: clf.predict(x))
plt.title("Logistic Regression")
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %% [markdown]
# It does an ok-ish job, but you can see there are still a lot of movies that are mis-classified.

# %% [markdown]
# ### Neural Network

# %% [markdown]
# Now we'll build a 3-layer neural network with one input layer, one hidden layer, and one output layer. The number of nodes in the input layer must match the numbeer of features of our data (2) and the number of nodes in our output layer must match the number of classes we are looking to separate (2). (Note, typically for binary classification problems like this you can use just one output node to represent the probability, p, of a new data point falling into one class, and the probability of it belonging to the other class will just be 1-p, however using two output nodes makes it easier to generalize this example to more classes).
#
# Our network will look like this:

# %% [markdown]
# ![nn_architecture.png](attachment:nn_architecture.png)

# %% [markdown]
# We can choose the dimensionality (the number of nodes) of the hidden layer. The more nodes we put into the hidden layer the more complex functions we will be able fit. But higher dimensionality comes at a cost. First, more computation is required to make predictions and learn the network parameters. A bigger number of parameters also means we become more prone to overfitting our data.
#
# How to choose the size of the hidden layer? While there are some general guidelines and recommendations, it always depends on your specific problem and is more of an art than a science. We will play with the number of nodes in the hidden layer later on and see how it affects our output.
#
# We also need to pick an activation function for our hidden layer. The activation function transforms the inputs of the layer into its outputs. A nonlinear activation function is what allows us to fit nonlinear hypotheses. Common chocies for activation functions are tanh, the sigmoid function, or ReLUs. We will use tanh, which performs quite well in many scenarios. A nice property of these functions is that their derivate can be computed using the original function value. For example, the derivative of $\tanh x$ is $1-\tanh^2 x$. This is useful because it allows us to compute $\tanh x$ once and re-use its value later on to get the derivative.
#
# Because we want our network to output probabilities the activation function for the output layer will be the softmax, which is simply a way to convert raw scores to probabilities. If you're familiar with the logistic function you can think of softmax as its generalization to multiple classes.

# %% [markdown]
# #### Network Predictions

# %% [markdown]
# Our network makes predictions using forward propagation, which is just a bunch of matrix multiplications and the application of the activation function(s) we defined above. If $x$ is the 2-dimensional input to our network then we calculate our prediction $\hat{y}$ (also two-dimensional) as follows:
#
# $$
# \begin{aligned}
# z_1 = xW_1 + b_1 \\
# a_1 = \tanh(z_1) \\
# z_2 = a_1W_2 + b_2 \\
# a_2 = \hat{y} = \mathrm{softmax}(z_2)
# \end{aligned}
# $$
#
# $z_i$ is the weighted sum of inputs of layer $i$ (bias included) and $a_i$ is the output of layer $i$ after applying the activation function. $W_1, b_1, W_2, b_2$ are parameters of our network, which we need to learn from our training data. You can think of them as matrices transforming data between layers of the network. Looking at the matrix multiplications above we can figure out the dimensionality of these matrices. If we use 500 nodes for our hidden layer then $W_1 \in \mathbb{R}^{2\times500}$, $b_1 \in \mathbb{R}^{500}$, $W_2 \in \mathbb{R}^{500\times2}$, $b_2 \in \mathbb{R}^{2}$. Now you see why we have more parameters if we increase the size of the hidden layer.

# %% [markdown]
# #### Learning the Parameters
#
# Remember, to train our network we need to define a loss function that we try to minimize. A common choice with softmax output is the cross-entropy loss. For N training examples and C classes, the  loss for our prediction $\hat{y}$ with respect to the true labels $y$ is given by:
#
# $$
# \begin{aligned}
# L(y,\hat{y}) = - \frac{1}{N} \sum_{n \in N} \sum_{i \in C} y_{n,i} \log\hat{y}_{n,i}
# \end{aligned}
# $$
#
# We'll use gradient descent to (try) to find the minimum of this loss function. Using the standard back propagation algorithm, the parameters of our network will be updated according to:
#
# $$
# \begin{aligned}
# \delta_3 = \hat{y} - y \\
# \delta_2 = (1 - \tanh^2z_1) \circ \delta_3W_2^T \\
# \frac{\partial{L}}{\partial{W_2}} = a_1^T \delta_3  \\
# \frac{\partial{L}}{\partial{b_2}} = \delta_3\\
# \frac{\partial{L}}{\partial{W_1}} = x^T \delta_2\\
# \frac{\partial{L}}{\partial{b_1}} = \delta_2 \\
# \end{aligned}
# $$

# %% [markdown]
# #### Implementation
# Ok, let's start building! We'll start by defining some useful parameters for our gradient descent algorithm:

# %%
num_examples = len(X) # training set size
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality

# Gradient descent parameters (I picked these by hand)
epsilon = 0.01 # learning rate for gradient descent
reg_lambda = 0.01 # regularization strength

# %% [markdown]
# Now let's implement the loss function (softmax)

# %%
# Helper function to evaluate the total loss on the dataset
def calculate_loss(model):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    # Forward propagation to calculate our predictions
    z1 = X.dot(W1) + b1
    a1 = np.tanh(z1)
    z2 = a1.dot(W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    # Calculating the loss
    corect_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(corect_logprobs)
    # Add regulatization term to loss (optional)
    data_loss += reg_lambda/2 * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
    return 1./num_examples * data_loss

# %% [markdown]
# And now let's define what a forward pass of the network looks like. This is how the network will make predictions about the movies (classify them as 1 or 0). It will process the movie data through the entire network and return the class with the highest predicted probability.

# %%
# Helper function to predict an output (0 or 1)
def predict(model, x):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    # Forward propagation
    z1 = x.dot(W1) + b1
    a1 = np.tanh(z1)
    z2 = a1.dot(W2) + b2
    exp_scores = np.exp(z2)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    return np.argmax(probs, axis=1)

# %% [markdown]
# We can now set up the function to train our NN! It uses our loss function and parameters from above to run a batch gradient descent and optimize the network.

# %%
# This function learns parameters for the neural network and returns the model.
# - nn_hdim: Number of nodes in the hidden layer
# - num_passes: Number of passes through the training data for gradient descent
# - print_loss: If True, print the loss every 1000 iterations
def build_model(nn_hdim, num_passes=20000, print_loss=False):
    
    # Initialize the parameters to random values. We need to learn these.
    np.random.seed(0)
    W1 = np.random.randn(nn_input_dim, nn_hdim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, nn_hdim))
    W2 = np.random.randn(nn_hdim, nn_output_dim) / np.sqrt(nn_hdim)
    b2 = np.zeros((1, nn_output_dim))

    # This is what we return at the end
    model = {}
    
    # Gradient descent. For each batch...
    for i in range(0, num_passes):

        # Forward propagation
        z1 = X.dot(W1) + b1
        a1 = np.tanh(z1)
        z2 = a1.dot(W2) + b2
        exp_scores = np.exp(z2)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

        # Backpropagation
        delta3 = probs
        delta3[range(num_examples), y] -= 1
        dW2 = (a1.T).dot(delta3)
        db2 = np.sum(delta3, axis=0, keepdims=True)
        delta2 = delta3.dot(W2.T) * (1 - np.power(a1, 2))
        dW1 = np.dot(X.T, delta2)
        db1 = np.sum(delta2, axis=0)

        # Add regularization terms (b1 and b2 don't have regularization terms)
        dW2 += reg_lambda * W2
        dW1 += reg_lambda * W1

        # Gradient descent parameter update
        W1 += -epsilon * dW1
        b1 += -epsilon * db1
        W2 += -epsilon * dW2
        b2 += -epsilon * db2
        
        # Assign new parameters to the model
        model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
        
        # Optionally print the loss.
        # This is expensive because it uses the whole dataset, so we don't want to do it too often.
        if print_loss and i % 1000 == 0:
          print("Loss after iteration %i: %f" %(i, calculate_loss(model)))
    
    return model

# %% [markdown]
# We can specify the number of nodes in our hidden layer in the above function. Let's try first with 3 nodes:

# %%
# Build a model with a 3-dimensional hidden layer
model = build_model(3, print_loss=True)

# Plot the decision boundary
plot_decision_boundary(lambda x: predict(model, x))
plt.title("Decision Boundary for hidden layer size 3")
# Out:
# Loss after iteration 0: 0.432387
# Loss after iteration 1000: 0.068947
# Loss after iteration 2000: 0.068901
# Loss after iteration 3000: 0.071218
# Loss after iteration 4000: 0.071253
# Loss after iteration 5000: 0.071278
# Loss after iteration 6000: 0.071293
# Loss after iteration 7000: 0.071303
# Loss after iteration 8000: 0.071308
# Loss after iteration 9000: 0.071312
# Loss after iteration 10000: 0.071314
# Loss after iteration 11000: 0.071315
# Loss after iteration 12000: 0.071315
# Loss after iteration 13000: 0.071316
# Loss after iteration 14000: 0.071316
# Loss after iteration 15000: 0.071316
# Loss after iteration 16000: 0.071316
# Loss after iteration 17000: 0.071316
# Loss after iteration 18000: 0.071316
# Loss after iteration 19000: 0.071316
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 3')

# %% [markdown]
# This definitely did a better job than our linear regression algorithm! Try the below exercises to explore the model further

# %% [markdown]
# **Exercise:** Train multiple networks with a range of hidden dimension sizes and explore the effect this has on the decision boundary.

# %%
## Your solution

# %% [markdown]
# **Exercise:** Train multiple networks with different learning rates and explore the effect on the decision boundary. Bonus: implement a decaying learning rate that decreases with training epochs.

# %%
## Your solution

# %% [markdown]
# **Exercise:** Extend the network to four layers. Note you will have to adjust both the forward and backward propagation functions.

# %%
## Your solution

# %% [markdown]
# **Exercise:** Extend the network to three classes. Note you will have to generate an appropriate dataset for this.

# %%
## Your solution

# %% [markdown]
# ## Part 2: Neural Networks in Keras
# Phew...that was quite a bit of coding. Now we'll learn how to train a NN in Keras in just a few lines of code. This lesson is adapted from the [Keras Tutorial](https://www.tensorflow.org/tutorials/keras/classification)
#
# For this example, we'll use the [Fashion MNIST] dataset which contains 70,000 grayscale images of individual clothing items in 10 categories. Each image is low resolution (28x28 pixels) so we can use them as training data for a standard neural network; for higher resolution images it becomes impractical to train a standard NN and we instead use Convolutional Neural Networks which we will learn about tomorrow.
#
# You can see an example of some images from Fashion MNIST below:
# ![fashion_mnist.png](attachment:fashion_mnist.png)

# %% [markdown]
# For this lesson we'll use 60,000 images to train the network and 10,000 images for our validation set. Remember, in a real implementation you'd want to have a second hold-out test dataset to evaluate the final performance of your model.
#
# Let's load the data:

# %%
#import keras 
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.0.0

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 1s 0us/step

# %% [markdown]
# This created four numpy arrays: test and training data (X) and test and training labels. The labels are an array of integers ranging from 0 to 9 representing the class of clothing shown in the image
# ![fashion_labels.png](attachment:fashion_labels.png)

# %% [markdown]
# The actual name labels aren't included in the dataset, so we can store the names to use later when we plot the results

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# #### Explore the Data
# Let's take a look at the format of the dtaset before traiing our model

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# This shows that, as expected, our training set is 60,000 images represented as 28x8 pixel maps, and 60,000 labels composed of integers in the range 0-9.

# %% [markdown]
# #### Preprocess the data
#
# We must prepare the data in a format that can be used to train the NN. Let's take a look at the first image in our dataset:

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# We can see the pixel values ran from 0 to 255. Let's scale these to fall between 0 and 1 instead, to reduce the variance and make the network easier to train. Note, we must transform both the training and test set.

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# Let's check our transformation by showing the first 25 training images and their corresponding labels:

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# Looks good!

# %% [markdown]
# #### Build the model
#
# We'll start by configuring the layers of the model. `tf.keras.layers.Dense` creates a layer for a fully connected feed-forward NN.
#
# Our first layer will flatten the input image to a one-dimensinoal array of 28x28=784 pixels so it can be used as input to a standard NN. We can think of this as unstacking the rows of the image and putting them next to each other.
#
# Our NN then has 2 standard layers: a hidden layer with 128 nodes and an output layer with 10 nodes, corresponding to the 10 classes in our dataset.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %% [markdown]
# That's all it takes to define our NN model! We now need to specify model settings like loss function, optimizier, and evaluation metrics. Again, this is very simple in Keras.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Now we'll train our network! Remember, this process consists of several steps:
# 1. Feed training data through model.
# 2. Predict initial classification labels.
# 3. Compare predicted to truth labels.
# 4. Backpropagate errors through the network to move the loss function towards its minima

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.4941 - accuracy: 0.8279
# Epoch 2/10
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.3709 - accuracy: 0.8651
# Epoch 3/10
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.3355 - accuracy: 0.8771
# Epoch 4/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.3120 - accuracy: 0.8857
# Epoch 5/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.2934 - accuracy: 0.8912
# Epoch 6/10
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.2784 - accuracy: 0.8966
# Epoch 7/10
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.2666 - accuracy: 0.9005
# Epoch 8/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.2558 - accuracy: 0.9045
# Epoch 9/10
# ...

# %% [markdown]
# Now we'll test how the model performs on the test dataset:

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 10000/1 - 1s - loss: 0.2595 - accuracy: 0.8797
#
# Test accuracy: 0.8797

# %% [markdown]
# The accuracy on our testing dataset is a bit lower than training...what could this indicate? (possible overtraining)

# %% [markdown]
# Right now, the output of our model is [logits](https://developers.google.com/machine-learning/glossary#logits). Let's append a softmax layer to convert the logits to probabilities (you could also have included this layer in the original network design).

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
# create the interpretable predictions for test set
predictions = probability_model.predict(test_images)

# %%
# look at the prediction for the first image
predictions[0]
# Out:
# array([4.3547921e-06, 4.0847908e-07, 7.1462463e-09, 6.7538586e-10,
#        1.6002289e-08, 3.2611052e-03, 1.3549253e-07, 3.9394267e-02,
#        2.4811757e-07, 9.5733941e-01], dtype=float32)

# %% [markdown]
# This array represents the probability that the image falls into each of the 10 categories. Let's see which one is the highest.

# %%
# get the highest probability
np.argmax(predictions[0])
# Out:
# 9

# %%
# check the label
class_names[np.argmax(predictions[0])]
# Out:
# 'Ankle boot'

# %% [markdown]
# It learned the right label!

# %%
#create a function to plot a histogram of all class predictions for an image
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %% [markdown]
# Let's look at several examples and explore the model performance.

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %% [markdown]
# It's interesting to notice that the network can sometimes be very confident even when it's prediction is incorrect

# %% [markdown]
# **Exercise:** adust the model to reduce overtraining. Note there are several different ways you could do this!

# %%
## YOUR SOLUTION

# %% [markdown]
# **Exercise:** Does the network perform similary on all classes?

# %%
## YOUR SOLUTION

# %% [markdown]
# ### Hyperparameter Optimization
# Keras has a built in functionality to help you pick the best set of hyperparameters for your model. This example is adapted from the [Keras Tutorial](https://www.tensorflow.org/tutorials/keras/keras_tuner).

# %%
# !pip install -q -U keras-tuner
import kerastuner as kt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-51-5d7b6944a6ac> in <module>
#       1 get_ipython().system('pip install -q -U keras-tuner')
# ----> 2 import kerastuner as kt
#
# ~/miniconda2/envs/wintersession/lib/python3.7/site-packages/kerastuner/__init__.py in <module>
#      17 from __future__ import print_function
#      18
# ---> 19 from . import applications
#      20 from . import oracles
#      21 from . import tuners
#
# ~/miniconda2/envs/wintersession/lib/python3.7/site-packages/kerastuner/applications/__init__.py in <module>
#      17 from .resnet import HyperResNet
#      18 from .xception import HyperXception
# ---> 19 from .augment import HyperImageAugment
#
# ~/miniconda2/envs/wintersession/lib/python3.7/site-packages/kerastuner/applications/augment.py in <module>
#      24
#      25 from tensorflow.keras import layers
# ...

# %% [markdown]
# We'll define a hypermodel here that a tests a range of learning rates.

# %%
def model_builder(hp):
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=(28, 28)))

  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units = hp.Int('units', min_value = 32, max_value = 512, step = 32)
  model.add(keras.layers.Dense(units = hp_units, activation = 'relu'))
  model.add(keras.layers.Dense(10))

  # Tune the learning rate for the optimizer 
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4]) 

  model.compile(optimizer = keras.optimizers.Adam(learning_rate = hp_learning_rate),
                loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
                metrics = ['accuracy'])

  return model

# %% [markdown]
# Now we'll initiate the Keras tuner and perform the hyperparameter tuning. There are four tuners you can use: RandomSearch, Hyperband, BayesianOptimization, and SKlearn. Here we'll use the [Hyperband](https://arxiv.org/pdf/1603.06560.pdf) optimizer.
#
# We have to specify the hypermodel, the object to optimize over, and the maximum number of epochs to train.

# %%
tuner = kt.Hyperband(model_builder,
                     objective = 'val_accuracy', 
                     max_epochs = 10,
                     factor = 3,
                     directory = 'my_dir',
                     project_name = 'intro_to_kt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-16d882b0d11b> in <module>
# ----> 1 tuner = kt.Hyperband(model_builder,
#       2                      objective = 'val_accuracy',
#       3                      max_epochs = 10,
#       4                      factor = 3,
#       5                      directory = 'my_dir',
#
# NameError: name 'kt' is not defined

# %% [markdown]
# The Hyperband tuning algorithm uses adaptive resource allocation and early-stopping to quickly converge on a high-performing model. This is done using a sports championship style bracket. The algorithm trains a large number of models for a few epochs and carries forward only the top-performing half of models to the next round. Hyperband determines the number of models to train in a bracket by computing 1 + logfactor(max_epochs) and rounding it up to the nearest integer.
#
# Before running the hyperparameter search, define a callback to clear the training outputs at the end of every training step.

# %%
class ClearTrainingOutput(tf.keras.callbacks.Callback):
  def on_train_end(*args, **kwargs):
    IPython.display.clear_output(wait = True)

# %% [markdown]
# Run the hyperparameter search. The arguments for the search method are the same as those used for tf.keras.model.fit in addition to the callback above.

# %%
tuner.search(img_train, label_train, epochs = 10, validation_data = (img_test, label_test), callbacks = [ClearTrainingOutput()])

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-6c7db414496e> in <module>
# ----> 1 tuner.search(img_train, label_train, epochs = 10, validation_data = (img_test, label_test), callbacks = [ClearTrainingOutput()])
#       2
#       3 # Get the optimal hyperparameters
#       4 best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]
#       5
#
# NameError: name 'tuner' is not defined

# %% [markdown]
# Now we can retrain the model with the optimal hyperparameters found in our search!

# %%
# Build the model with the optimal hyperparameters and train it on the data
model = tuner.hypermodel.build(best_hps)
model.fit(img_train, label_train, epochs = 10, validation_data = (img_test, label_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0882f032a841> in <module>
#       1 # Build the model with the optimal hyperparameters and train it on the data
# ----> 2 model = tuner.hypermodel.build(best_hps)
#       3 model.fit(img_train, label_train, epochs = 10, validation_data = (img_test, label_test))
#
# NameError: name 'tuner' is not defined

# %% [markdown]
# Exercise: Repeat the above process to tune a different hyperparameter (you might need to add the functionality to the model to test things like momentum or regularization).

# %%
## YOUR SOLUTION
